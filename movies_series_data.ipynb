# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Ricky\OneDrive\Desktop\DATA SETS\movies_youtube_sentiments.csv")

# %%
data
# Out:
#                                      name  \
# 0     Harry Potter and the Goblet of Fire
# 1                  The 40-Year-Old Virgin
# 2                     Memoirs of a Geisha
# 3                       Pride & Prejudice
# 4                           Batman Begins
# ...                                   ...
# 1100                 Assassination Nation
# 1101                 Unfriended: Dark Web
# 1102   The Nutcracker and the Four Realms
# 1103                         Little Italy
# 1104                The Happytime Murders
#
#                                      trailer_link     video_id  \
# 0     https://www.youtube.com/watch?v=3EGojp4Hh6I  3EGojp4Hh6I
# 1     https://www.youtube.com/watch?v=YnDeJn-BX5Q  YnDeJn-BX5Q
# 2     https://www.youtube.com/watch?v=4L-xlmakQvc  4L-xlmakQvc
# 3     https://www.youtube.com/watch?v=Ur_DIHs92NM  Ur_DIHs92NM
# 4     https://www.youtube.com/watch?v=neY2xVmOfUM  neY2xVmOfUM
# ...                                           ...          ...
# ...

# %%
data.shape
# Out:
# (1105, 18)

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (900, 18)

# %%
pd.isnull(data)
# Out:
#        name  trailer_link  video_id  sentiment_scores  favorability  rating  \
# 0     False         False     False             False         False   False
# 1     False         False     False             False         False   False
# 2     False         False     False             False         False   False
# 3     False         False     False             False         False   False
# 4     False         False     False             False         False   False
# ...     ...           ...       ...               ...           ...     ...
# 1096  False         False     False             False         False   False
# 1100  False         False     False             False         False   False
# 1101  False         False     False             False         False   False
# 1102  False         False     False             False         False   False
# 1104  False         False     False             False         False   False
#
# ...

# %%
pd.isnull(data).sum()
# Out:
# name                0
# trailer_link        0
# video_id            0
# sentiment_scores    0
# favorability        0
# rating              0
# genre               0
# year                0
# released            0
# votes               0
# director            0
# writer              0
# star                0
# country             0
# budget              0
# gross               0
# company             0
# runtime             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 900 entries, 0 to 1104
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              900 non-null    object
#  1   trailer_link      900 non-null    object
#  2   video_id          900 non-null    object
#  3   sentiment_scores  900 non-null    object
#  4   favorability      900 non-null    float64
#  5   rating            900 non-null    object
#  6   genre             900 non-null    object
#  7   year              900 non-null    int64
#  8   released          900 non-null    object
#  9   votes             900 non-null    float64
#  10  director          900 non-null    object
#  11  writer            900 non-null    object
#  12  star              900 non-null    object
#  13  country           900 non-null    object
#  14  budget            900 non-null    float64
#  15  gross             900 non-null    float64
# ...

# %%
data['votes'] = data['votes'].astype('int')

# %%
data['favorability'] = data['favorability'].astype('int')

# %%
data['budget'] = data['budget'].astype('int')

# %%
data['gross'] = data['gross'].astype('int')

# %%
data['runtime'] = data['runtime'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 900 entries, 0 to 1104
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              900 non-null    object
#  1   trailer_link      900 non-null    object
#  2   video_id          900 non-null    object
#  3   sentiment_scores  900 non-null    object
#  4   favorability      900 non-null    int32
#  5   rating            900 non-null    object
#  6   genre             900 non-null    object
#  7   year              900 non-null    int64
#  8   released          900 non-null    object
#  9   votes             900 non-null    int32
#  10  director          900 non-null    object
#  11  writer            900 non-null    object
#  12  star              900 non-null    object
#  13  country           900 non-null    object
#  14  budget            900 non-null    int32
#  15  gross             900 non-null    int32
# ...

# %%
data.columns
# Out:
# Index(['name', 'trailer_link', 'video_id', 'sentiment_scores', 'favorability',
#        'rating', 'genre', 'year', 'released', 'votes', 'director', 'writer',
#        'star', 'country', 'budget', 'gross', 'company', 'runtime'],
#       dtype='object')

# %%
data
# Out:
#                                      name  \
# 0     Harry Potter and the Goblet of Fire
# 1                  The 40-Year-Old Virgin
# 2                     Memoirs of a Geisha
# 3                       Pride & Prejudice
# 4                           Batman Begins
# ...                                   ...
# 1096                    Welcome to Marwen
# 1100                 Assassination Nation
# 1101                 Unfriended: Dark Web
# 1102   The Nutcracker and the Four Realms
# 1104                The Happytime Murders
#
#                                      trailer_link     video_id  \
# 0     https://www.youtube.com/watch?v=3EGojp4Hh6I  3EGojp4Hh6I
# 1     https://www.youtube.com/watch?v=YnDeJn-BX5Q  YnDeJn-BX5Q
# 2     https://www.youtube.com/watch?v=4L-xlmakQvc  4L-xlmakQvc
# 3     https://www.youtube.com/watch?v=Ur_DIHs92NM  Ur_DIHs92NM
# 4     https://www.youtube.com/watch?v=neY2xVmOfUM  neY2xVmOfUM
# ...                                           ...          ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your data variable contains your dataset

# First, let's find the top 10 countries
top_10_countries = data['country'].value_counts().head(10).index.tolist()

# Filter the data to include only the top 10 countries
filtered_data = data[data['country'].isin(top_10_countries)]

# Create the countplot
ax = sns.countplot(x="country", data=filtered_data, order=top_10_countries)

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your data variable contains your dataset

# First, let's find the top 10 genres
top_10_genres = data['genre'].value_counts().head(10).index.tolist()

# Filter the data to include only the top 10 genres
filtered_data = data[data['genre'].isin(top_10_genres)]

# Create the countplot
ax = sns.countplot(x="genre", data=filtered_data, order=top_10_genres)

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
data
# Out:
#                                      name  \
# 0     Harry Potter and the Goblet of Fire
# 1                  The 40-Year-Old Virgin
# 2                     Memoirs of a Geisha
# 3                       Pride & Prejudice
# 4                           Batman Begins
# ...                                   ...
# 1096                    Welcome to Marwen
# 1100                 Assassination Nation
# 1101                 Unfriended: Dark Web
# 1102   The Nutcracker and the Four Realms
# 1104                The Happytime Murders
#
#                                      trailer_link     video_id  \
# 0     https://www.youtube.com/watch?v=3EGojp4Hh6I  3EGojp4Hh6I
# 1     https://www.youtube.com/watch?v=YnDeJn-BX5Q  YnDeJn-BX5Q
# 2     https://www.youtube.com/watch?v=4L-xlmakQvc  4L-xlmakQvc
# 3     https://www.youtube.com/watch?v=Ur_DIHs92NM  Ur_DIHs92NM
# 4     https://www.youtube.com/watch?v=neY2xVmOfUM  neY2xVmOfUM
# ...                                           ...          ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your data variable contains your dataset

# First, let's find the top 10 movies based on vote count
top_10_movies = data.nlargest(10, 'votes')

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
ax = sns.barplot(x="name", y="votes", data=top_10_movies, palette="viridis")

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Set labels and title
ax.set_xlabel('Movie Name')
ax.set_ylabel('Votes')
ax.set_title('Top 10 Movies by Votes')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your data variable contains your dataset

# First, let's find the top 10 directors based on vote count
top_10_directors = data.groupby('director')['votes'].sum().nlargest(10).index.tolist()
top_10_directors_data = data[data['director'].isin(top_10_directors)]

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
ax = sns.barplot(x="director", y="votes", data=top_10_directors_data, estimator=sum, errorbar=None, palette="viridis")

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Set labels and title
ax.set_xlabel('Director')
ax.set_ylabel('Total Votes')
ax.set_title('Top 10 Directors by Total Votes')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your data variable contains your dataset

# First, let's find the top 10 directors based on vote count
top_10_directors = data.groupby('director')['votes'].sum().nlargest(10).index.tolist()
top_10_directors_data = data[data['director'].isin(top_10_directors)]

# Calculate the total votes for each director
director_votes = top_10_directors_data.groupby('director')['votes'].sum().reset_index()

# Sort the directors based on their total votes in descending order
director_votes_sorted = director_votes.sort_values(by='votes', ascending=False)

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
ax = sns.barplot(x="director", y="votes", data=director_votes_sorted, palette="viridis")

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Set labels and title
ax.set_xlabel('Director')
ax.set_ylabel('Total Votes')
ax.set_title('Top 10 Directors by Total Votes (Descending Order)')

# Show the plot
plt.show()
